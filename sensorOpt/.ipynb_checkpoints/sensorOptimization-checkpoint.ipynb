# %% [markdown]
# ### Data handling for sensor location optimization

# %%
import pyvista as vtki
import numpy as np
import matplotlib.pyplot as plt
import ipyvtklink.viewer as link
import scipy.io as io
import scipy as sp
import cvxpy as cp


grid = vtki.UnstructuredGrid('./VTK/sensorOpt_57000.vtk')
wing = vtki.PolyData('./VTK/wing/wing_57000.vtk')

p_raw = grid['p']

pts = grid.points
wingpts = wing.points

selection = np.zeros(np.shape(pts)[0])
sel2 = np.zeros(np.shape(wingpts)[0])

for i in range(np.shape(pts)[0]):
    if pts[i,2] == -.25:
        selection[i] = i

for i in range(np.shape(wingpts)[0]):
    if wingpts[i,2] == -.25:
        sel2[i] = i
        
gridind = np.nonzero(selection)        
wingind = np.nonzero(sel2)

p = p_raw[gridind]
pts = np.squeeze(pts[gridind,0:2])
wingpts = np.squeeze(wingpts[wingind,0:2])

nrows, ncols = pts.shape
dtype={'names':['f{}'.format(i) for i in range(ncols)],
       'formats':ncols * [pts.dtype]}

wingindex = np.in1d(pts.view(dtype), wingpts.view(dtype))

pwing = p[wingindex]

# %%
N = np.shape(p)[0]
P = 10
perm = np.random.permutation(N)[0:P]
x = p
y = x[perm]
Psi = np.eye(N,N,dtype='int8')
theta = Psi[perm]

s = cp.Variable(N)
v = cp.Variable((P,N))
obj = cp.Minimize(cp.norm(s))
constraint = [ y == v@s]
prob = cp.Problem(obj,constraint)

result = prob.solve(verbose = False)

print(s.value)
# Out:
# ---------------------------------------------------------------------------
# DCPError                                  Traceback (most recent call last)
# /tmp/ipykernel_6968/1801404301.py in <module>
#      13 prob = cp.Problem(obj,constraint)
#      14
# ---> 15 result = prob.solve(verbose = False)
#      16
#      17 print(s.value)
#
# ~/.local/lib/python3.8/site-packages/cvxpy/problems/problem.py in solve(self, *args, **kwargs)
#     460         else:
#     461             solve_func = Problem._solve
# --> 462         return solve_func(self, *args, **kwargs)
#     463
#     464     @classmethod
#
# ~/.local/lib/python3.8/site-packages/cvxpy/problems/problem.py in _solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, **kwargs)
#     947                 return self.value
#     948
# --> 949         data, solving_chain, inverse_data = self.get_problem_data(
#     950             solver, gp, enforce_dpp, verbose)
#     951
#
# ~/.local/lib/python3.8/site-packages/cvxpy/problems/problem.py in get_problem_data(self, solver, gp, enforce_dpp, verbose)
#     568         if key != self._cache.key:
#     569             self._cache.invalidate()
# --> 570             solving_chain = self._construct_chain(
#     571                 solver=solver, gp=gp, enforce_dpp=enforce_dpp)
#     572             self._cache.key = key
#
# ~/.local/lib/python3.8/site-packages/cvxpy/problems/problem.py in _construct_chain(self, solver, gp, enforce_dpp)
#     796         candidate_solvers = self._find_candidate_solvers(solver=solver, gp=gp)
#     797         self._sort_candidate_solvers(candidate_solvers)
# --> 798         return construct_solving_chain(self, candidate_solvers, gp=gp,
#     799                                        enforce_dpp=enforce_dpp)
#     800
#
# ~/.local/lib/python3.8/site-packages/cvxpy/reductions/solvers/solving_chain.py in construct_solving_chain(problem, candidates, gp, enforce_dpp)
#     153     if len(problem.variables()) == 0:
#     154         return SolvingChain(reductions=[ConstantSolver()])
# --> 155     reductions = _reductions_for_problem_class(problem, candidates, gp)
#     156
#     157     dpp_context = 'dcp' if not gp else 'dgp'
#
# ~/.local/lib/python3.8/site-packages/cvxpy/reductions/solvers/solving_chain.py in _reductions_for_problem_class(problem, candidates, gp)
#      89             append += ("\nHowever, the problem does follow DQCP rules. "
#      90                        "Consider calling solve() with `qcp=True`.")
# ---> 91         raise DCPError(
#      92             "Problem does not follow DCP rules. Specifically:\n" + append)
#      93     elif gp and not problem.is_dgp():
#
# DCPError: Problem does not follow DCP rules. Specifically:
# The following constraints are not DCP:
# var77309 @ var77308 == [ 3.41394991e-02  6.95247017e-03  2.21991992e+00  4.34069991e-01
#  -4.09972996e-01  8.37218985e-02  6.66639011e-04 -6.85055971e-01
#  -2.22139001e-01  2.67593991e-02] , because the following subexpressions are not:
# |--  var77309 @ var77308

# %%
import cvxpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_4618/3890277531.py in <module>
# ----> 1 import cvxpy
#
# ModuleNotFoundError: No module named 'cvxpy'

# %%
x = np.array([1,2,3,4,6,8,4])
G = np.outer(x.T,x)
print(G)

[V,D] = np.linalg.eig(G)
print(D)
# Out:
# [[ 1  2  3  4  6  8  4]
#  [ 2  4  6  8 12 16  8]
#  [ 3  6  9 12 18 24 12]
#  [ 4  8 12 16 24 32 16]
#  [ 6 12 18 24 36 48 24]
#  [ 8 16 24 32 48 64 32]
#  [ 4  8 12 16 24 32 16]]
# [[-0.99656946+0.j         -0.08276059+0.j         -0.05524197+0.j
#    0.00383415-0.15842844j  0.00383415+0.15842844j  0.6536478 +0.j
#    0.99656946+0.j        ]
#  [ 0.01374579+0.j         -0.16552118+0.j         -0.11048394+0.j
#    0.14489778-0.01647256j  0.14489778+0.01647256j -0.02206935+0.j
#   -0.01374579+0.j        ]
#  [ 0.02061868+0.j         -0.24828177+0.j          0.37196258+0.j
#   -0.07727897+0.22112729j -0.07727897-0.22112729j -0.0547128 +0.j
#   -0.02061868+0.j        ]
#  [ 0.02749157+0.j         -0.33104236+0.j         -0.22096787+0.j
#   -0.02317758-0.24654144j -0.02317758+0.24654144j -0.71659336+0.j
#   -0.02749157+0.j        ]
#  [ 0.04123736+0.j         -0.49656353+0.j          0.74392517+0.j
#   -0.75685528+0.j         -0.75685528-0.j          0.06516737+0.j
#   -0.04123736+0.j        ]
#  [ 0.05498314+0.j         -0.66208471+0.j         -0.44193574+0.j
#    0.45720492+0.05141574j  0.45720492-0.05141574j  0.20299985+0.j
#   -0.05498314+0.j        ]
#  [ 0.02749157+0.j         -0.33104236+0.j         -0.22096787+0.j
#    0.22860246+0.02570787j  0.22860246-0.02570787j  0.10149992+0.j
#   -0.02749157+0.j        ]]

# %%
# Out:
# 2

# %%
# Out:
# ViewInteractiveWidget(height=768, layout=Layout(height='auto', width='100%'), width=1024)
