# %%
import os
files = os.listdir('./Animation')
print(files)
command = "apngasm output.png *.png"
for item in files:
    newname = "./Animation/{}.png".format(item[11:15])
    os.rename("./Animation/{}".format(item),newname)
# Out:
# ['coanda_osc.0079.png', 'coanda_osc.0076.png', 'coanda_osc.0097.png', 'coanda_osc.0087.png', 'coanda_osc.0092.png', 'coanda_osc.0077.png', 'coanda_osc.0089.png', 'coanda_osc.0064.png', 'coanda_osc.0069.png', 'coanda_osc.0066.png', 'coanda_osc.0100.png', 'coanda_osc.0095.png', 'coanda_osc.0093.png', 'coanda_osc.0071.png', 'coanda_osc.0063.png', 'coanda_osc.0088.png', 'coanda_osc.0096.png', 'coanda_osc.0075.png', 'coanda_osc.0080.png', 'coanda_osc.0073.png', 'coanda_osc.0101.png', 'coanda_osc.0065.png', 'coanda_osc.0099.png', 'coanda_osc.0098.png', 'coanda_osc.0061.png', 'coanda_osc.0094.png', 'coanda_osc.0074.png', 'coanda_osc.0084.png', 'coanda_osc.0085.png', 'coanda_osc.0083.png', 'coanda_osc.0068.png', 'coanda_osc.0082.png', 'coanda_osc.0067.png', 'coanda_osc.0091.png', 'coanda_osc.0090.png', 'coanda_osc.0078.png', 'coanda_osc.0081.png', 'coanda_osc.0070.png', 'coanda_osc.0072.png', 'coanda_osc.0062.png', 'coanda_osc.0086.png']

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 from airfoils import Airfoil
#       2 foil = Airfoil.NACA4('0006')
#       3 foil.y_lower(x=[.1,.2,.6,])
#
# ModuleNotFoundError: No module named 'airfoils'
