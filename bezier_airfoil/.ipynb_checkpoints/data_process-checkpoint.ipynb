# %%
def check_float(textin):
    try:
        float(textin)
        return True

    except ValueError:
        return False
    
def retrieve_lift(folder):
    import os
    import shutil
    import numpy as np
    
    files = os.listdir(folder)
    cleaned = [x for x in files if check_float(x)]
    files = sorted(cleaned)
    
    force_command = "rhoSimpleFoam -postProcess -case {} -func forces".format(folder)
    os.system(force_command)
    
    forces = np.zeros(3)
    moments = np.zeros(3)
    time = np.array([])
    
    for file in files:    
        with open("{}/postProcessing/forces/{}/forces.dat".format(folder,file)) as f:
            full = f.readlines()
            line = full[3]
            starts = []
            ends = []
            for i in range(len(line)):
                if line[i] == '(' and line[i+1] != '(':
                    starts.append(i+1)
                elif line[i] == ')' and line[i-1] != ')':
                    ends.append(i)
            pressure_forces = np.array([float(x) for x in line[starts[0]:ends[0]].split()])
            viscous_forces = np.array([float(x) for x in line[starts[1]:ends[1]].split()])

            pressure_moments = np.array([float(x) for x in line[starts[2]:ends[2]].split()])
            viscous_moments = np.array([float(x) for x in line[starts[3]:ends[3]].split()])
            forces = np.vstack([forces, pressure_forces + viscous_forces])
            moments = np.vstack([moments, pressure_moments + viscous_moments])
            time = np.append(time,float(file))
    return forces, moments, time

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

directory = '/media/james/Elements/afc_unsteady/'
cases = ['64a_osc']

forces_bl, moments_bl, time_bl = retrieve_lift(directory+cases[0])
# forces_up, moments_up, time_up = retrieve_lift(directory+cases[1])
# forces_down, moments_down, time_down = retrieve_lift(directory+cases[2])
# forces_osc, moments_osc, time_osc = retrieve_lift(directory+cases[3])
# Out:
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  10
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 10-b2f0c22c5002
# Exec   : rhoSimpleFoam -postProcess -case /media/james/Elements/afc_unsteady/64a_osc -func forces
# Date   : Sep 08 2022
# Time   : 17:08:22
# Host   : "james-xps"
# PID    : 17561
# I/O    : uncollated
# Case   : /media/james/Elements/afc_unsteady/64a_osc
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 5e-05
#         U: tolerance 5e-05
#         nuTilda: tolerance 5e-05
#
# Time = 0s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Using #calcEntry at line 28 in file "/media/james/Elements/afc_unsteady/64a_osc/0/U"
# Using #codeStream with "/media/james/Elements/afc_unsteady/64a_osc/dynamicCode/platforms/linux64GccDPInt32Opt/lib/libcodeStream_3a5e563e07ed5d6a5c128467ba4d071f039493ee.so"
# codeStream : dictionary:"/media/james/Elements/afc_unsteady/64a_osc/0/U" master-only-reading:0
# Using #calcEntry at line 28 in file "/media/james/Elements/afc_unsteady/64a_osc/0/U"
# Using #codeStream with "/media/james/Elements/afc_unsteady/64a_osc/dynamicCode/platforms/linux64GccDPInt32Opt/lib/libcodeStream_ef881cac620191f1d5d5a7ca2d85ff8805be7829.so"
# codeStream : dictionary:"/media/james/Elements/afc_unsteady/64a_osc/0/U" master-only-reading:0
# Using #calcEntry at line 51 in file "/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/meanFlow"
# codeStream : dictionary:"/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/meanFlow" master-only-reading:0
# Using #calcEntry at line 51 in file "/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/meanFlow"
# codeStream : dictionary:"/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/meanFlow" master-only-reading:0
# Using #calcEntry at line 52 in file "/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/meanFlow"
# codeStream : dictionary:"/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/meanFlow" master-only-reading:0
# Using #calcEntry at line 52 in file "/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/meanFlow"
# codeStream : dictionary:"/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/meanFlow" master-only-reading:0
# Using #calcEntry at line 66 in file "/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/coandaUpper/massFlowRateCoeffs"
# Using #codeStream with "/media/james/Elements/afc_unsteady/64a_osc/dynamicCode/platforms/linux64GccDPInt32Opt/lib/libcodeStream_1667c15096bbf573307cc428874b211e569ebada.so"
# codeStream : dictionary:"/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/coandaUpper/massFlowRateCoeffs" master-only-reading:0
# Using #calcEntry at line 67 in file "/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/coandaUpper/massFlowRateCoeffs"
# codeStream : dictionary:"/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/coandaUpper/massFlowRateCoeffs" master-only-reading:0
# Using #calcEntry at line 85 in file "/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/coandaLower/massFlowRateCoeffs"
# Using #codeStream with "/media/james/Elements/afc_unsteady/64a_osc/dynamicCode/platforms/linux64GccDPInt32Opt/lib/libcodeStream_f7a5b0fbeb0a8bb1bbc12d58357a86da06cdf9eb.so"
# codeStream : dictionary:"/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/coandaLower/massFlowRateCoeffs" master-only-reading:0
# Using #calcEntry at line 86 in file "/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/coandaLower/massFlowRateCoeffs"
# codeStream : dictionary:"/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/coandaLower/massFlowRateCoeffs" master-only-reading:0
# --> FOAM Warning :
#     From function static Foam::autoPtr<Foam::Function1<Type> > Foam::Function1<Type>::New(const Foam::word&, const Foam::dictionary&) [with Type = double]
#     in file /home/ubuntu/OpenFOAM/OpenFOAM-10/src/OpenFOAM/lnInclude/Function1New.C at line 106
#     Reading "/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/coandaUpper" from line 62 to line 69
#     Using deprecated "massFlowRateCoeffs" sub-dictionary.
#     Please use the simpler form
# amplitude
# {
#     type            constant;
#     value           0.003;
# }
# frequency       6;
# start           0;
# level
# {
#     type            constant;
#     value           0.003;
# }
# --> FOAM Warning :
#     From function static Foam::autoPtr<Foam::Function1<Type> > Foam::Function1<Type>::New(const Foam::word&, const Foam::dictionary&) [with Type = double]
#     in file /home/ubuntu/OpenFOAM/OpenFOAM-10/src/OpenFOAM/lnInclude/Function1New.C at line 106
#     Reading "/media/james/Elements/afc_unsteady/64a_osc/0/U/boundaryField/coandaLower" from line 81 to line 88
#     Using deprecated "massFlowRateCoeffs" sub-dictionary.
#     Please use the simpler form
# amplitude
# {
#     type            constant;
#     value           -0.003;
# }
# frequency       6;
# start           0;
# level
# {
#     type            constant;
#     value           0.003;
# }
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.54736 1.12266e-12 -2.23701e-17)
#         viscous  : (0.506155 -1.23385e-16 3.19994e-23)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64711e-18 -2.39678e-18 4.13003e-14)
#         viscous  : (2.16097e-24 2.65917e-24 1.18381e-17)
#         porous   : (0 0 0)
#
#
# Time = 0.0005s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (8.87719 0.0453406 -2.23204e-17)
#         viscous  : (0.459741 -0.000630895 9.28204e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64267e-18 -2.3936e-18 -0.000460924)
#         viscous  : (7.27835e-22 7.70319e-22 -4.58459e-06)
#         porous   : (0 0 0)
#
#
# Time = 0.001s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (6.85884 0.16377 -2.23439e-17)
#         viscous  : (0.387828 -0.00149653 8.91354e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.6456e-18 -2.39404e-18 -0.00369615)
#         viscous  : (7.02712e-22 7.32772e-22 -1.01361e-05)
#         porous   : (0 0 0)
#
#
# Time = 0.0015s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.71564 0.345512 -2.2378e-17)
#         viscous  : (0.357339 -0.00233108 8.83524e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64786e-18 -2.39725e-18 -0.012209)
#         viscous  : (6.95352e-22 7.24245e-22 -1.62148e-05)
#         porous   : (0 0 0)
#
#
# Time = 0.002s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.53319 0.57171 -2.2359e-17)
#         viscous  : (0.338025 -0.00309304 8.7317e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64705e-18 -2.3955e-18 -0.0275207)
#         viscous  : (6.8768e-22 7.1322e-22 -2.3084e-05)
#         porous   : (0 0 0)
#
#
# Time = 0.0025s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.71204 0.825189 -2.23525e-17)
#         viscous  : (0.323382 -0.00381132 8.68255e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64681e-18 -2.39495e-18 -0.0492314)
#         viscous  : (6.8276e-22 7.07992e-22 -3.21167e-05)
#         porous   : (0 0 0)
#
#
# Time = 0.003s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.77267 1.08243 -2.23475e-17)
#         viscous  : (0.313217 -0.0046173 8.64607e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64676e-18 -2.39451e-18 -0.0726115)
#         viscous  : (6.79126e-22 7.03875e-22 -4.37986e-05)
#         porous   : (0 0 0)
# Time = 0.0035s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.81278 1.33697 -2.2342e-17)
#         viscous  : (0.305213 -0.00538102 8.62513e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64671e-18 -2.39401e-18 -0.0949263)
#         viscous  : (6.76461e-22 7.01107e-22 -5.77987e-05)
#         porous   : (0 0 0)
#
#
# Time = 0.004s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.83933 1.57652 -2.23373e-17)
#         viscous  : (0.29886 -0.00604882 8.60918e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64668e-18 -2.3936e-18 -0.115904)
#         viscous  : (6.74308e-22 6.99033e-22 -7.32767e-05)
#         porous   : (0 0 0)
#
#
# Time = 0.0045s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.86108 1.80825 -2.23333e-17)
#         viscous  : (0.293754 -0.00689865 8.59823e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64666e-18 -2.39324e-18 -0.135917)
#         viscous  : (6.72486e-22 6.97391e-22 -9.00994e-05)
#         porous   : (0 0 0)
#
#
# Time = 0.005s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.87687 2.0441 -2.23293e-17)
#         viscous  : (0.289446 -0.00758179 8.59082e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64665e-18 -2.39289e-18 -0.155931)
#         viscous  : (6.70892e-22 6.96129e-22 -0.000107891)
#         porous   : (0 0 0)
#
#
# Time = 0.0055s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.89023 2.28147 -2.23246e-17)
#         viscous  : (0.285921 -0.00841201 8.58861e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64665e-18 -2.39247e-18 -0.176282)
#         viscous  : (6.69521e-22 6.9538e-22 -0.000126818)
#         porous   : (0 0 0)
#
#
# Time = 0.006s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.90464 2.51518 -2.23206e-17)
#         viscous  : (0.282924 -0.00911652 8.58812e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64664e-18 -2.39211e-18 -0.196413)
#         viscous  : (6.68338e-22 6.95022e-22 -0.000146511)
#         porous   : (0 0 0)
#
#
# Time = 0.0065s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.92035 2.74515 -2.23165e-17)
#         viscous  : (0.28032 -0.00987034 8.58733e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64663e-18 -2.39175e-18 -0.217403)
#         viscous  : (6.673e-22 6.94958e-22 -0.00016712)
#         porous   : (0 0 0)
#
#
# Time = 0.007s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.93909 2.98684 -2.23126e-17)
#         viscous  : (0.278077 -0.0106683 8.58944e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64662e-18 -2.39139e-18 -0.239182)
#         viscous  : (6.66375e-22 6.95173e-22 -0.000188904)
#         porous   : (0 0 0)
#
#
# Time = 0.0075s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.95776 3.23546 -2.23076e-17)
#         viscous  : (0.276156 -0.0114445 8.59488e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64662e-18 -2.39096e-18 -0.261646)
#         viscous  : (6.65539e-22 6.95698e-22 -0.000211563)
#         porous   : (0 0 0)
#
#
# Time = 0.008s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.97348 3.48049 -2.23039e-17)
#         viscous  : (0.274534 -0.0121919 8.60024e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64661e-18 -2.39062e-18 -0.28394)
#         viscous  : (6.64774e-22 6.96407e-22 -0.000235025)
#         porous   : (0 0 0)
#
#
# Time = 0.0085s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.99554 3.71762 -2.22996e-17)
#         viscous  : (0.273148 -0.0129722 8.6057e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64662e-18 -2.39023e-18 -0.307221)
#         viscous  : (6.64081e-22 6.97279e-22 -0.000259402)
#         porous   : (0 0 0)
#
#
# Time = 0.009s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (6.01847 3.97367 -2.22948e-17)
#         viscous  : (0.271904 -0.013761 8.61275e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64661e-18 -2.38981e-18 -0.33146)
#         viscous  : (6.63449e-22 6.984e-22 -0.000284916)
#         porous   : (0 0 0)
#
#
# Time = 0.0095s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (6.039 4.21822 -2.22909e-17)
#         viscous  : (0.270864 -0.0145496 8.61937e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64661e-18 -2.38947e-18 -0.35438)
#         viscous  : (6.6287e-22 6.99571e-22 -0.000311269)
#         porous   : (0 0 0)
#
#
# Time = 0.01s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (6.0664 4.47343 -2.22865e-17)
#         viscous  : (0.270016 -0.0154357 8.62522e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.6466e-18 -2.38906e-18 -0.379569)
#         viscous  : (6.62317e-22 7.00838e-22 -0.000338416)
#         porous   : (0 0 0)
#
#
# Time = 0.0105s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (6.09001 4.72263 -2.22814e-17)
#         viscous  : (0.269275 -0.0161701 8.63478e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.6466e-18 -2.38862e-18 -0.403596)
#         viscous  : (6.61838e-22 7.0239e-22 -0.000366336)
#         porous   : (0 0 0)
#
#
# Time = 0.011s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (6.11714 4.97121 -2.22778e-17)
#         viscous  : (0.268711 -0.0170645 8.64558e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.6466e-18 -2.38828e-18 -0.429568)
#         viscous  : (6.61358e-22 7.03822e-22 -0.000395057)
#         porous   : (0 0 0)
#
#
# Time = 0.0115s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (6.14451 5.22952 -2.22728e-17)
#         viscous  : (0.268263 -0.0178938 8.65658e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64659e-18 -2.38785e-18 -0.454615)
#         viscous  : (6.60942e-22 7.0539e-22 -0.000424677)
#         porous   : (0 0 0)
#
#
# Time = 0.012s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
# ...
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.74332 -7.3566 -2.24571e-17)
#         viscous  : (0.239502 -6.76949e-05 7.30863e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64658e-18 -2.40507e-18 1.23444)
#         viscous  : (6.53409e-22 5.58846e-22 0.00228714)
#         porous   : (0 0 0)
#
#
# Time = 0.496s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.72936 -7.11024 -2.24529e-17)
#         viscous  : (0.239057 -0.000868441 7.33906e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64658e-18 -2.40469e-18 1.212)
#         viscous  : (6.53412e-22 5.61441e-22 0.00226101)
#         porous   : (0 0 0)
#
#
# Time = 0.4965s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.71563 -6.86351 -2.24484e-17)
#         viscous  : (0.238727 -0.00154242 7.36968e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64658e-18 -2.40429e-18 1.18946)
#         viscous  : (6.53419e-22 5.64116e-22 0.0022343)
#         porous   : (0 0 0)
#
#
# Time = 0.497s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.70345 -6.61975 -2.24444e-17)
#         viscous  : (0.23844 -0.00232434 7.40154e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64658e-18 -2.40393e-18 1.16701)
#         viscous  : (6.53427e-22 5.66816e-22 0.002207)
#         porous   : (0 0 0)
#
#
# Time = 0.4975s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.69228 -6.35601 -2.24403e-17)
#         viscous  : (0.238156 -0.00309533 7.43376e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64658e-18 -2.40354e-18 1.14239)
#         viscous  : (6.53432e-22 5.69516e-22 0.00217912)
#         porous   : (0 0 0)
#
#
# Time = 0.498s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.68261 -6.07636 -2.2435e-17)
#         viscous  : (0.237946 -0.00377586 7.46689e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64658e-18 -2.40307e-18 1.11538)
#         viscous  : (6.53435e-22 5.72295e-22 0.00215014)
#         porous   : (0 0 0)
#
#
# Time = 0.4985s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.67655 -5.7949 -2.24298e-17)
#         viscous  : (0.237791 -0.00453373 7.50198e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64657e-18 -2.40261e-18 1.08746)
#         viscous  : (6.53443e-22 5.75139e-22 0.00212009)
#         porous   : (0 0 0)
#
#
# Time = 0.499s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.67189 -5.51229 -2.24252e-17)
#         viscous  : (0.237635 -0.00531557 7.53648e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64657e-18 -2.40218e-18 1.05884)
#         viscous  : (6.53453e-22 5.78005e-22 0.00208892)
#         porous   : (0 0 0)
#
#
# Time = 0.4995s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.66889 -5.22626 -2.24204e-17)
#         viscous  : (0.237545 -0.00598478 7.56913e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64656e-18 -2.40174e-18 1.03055)
#         viscous  : (6.53468e-22 5.80898e-22 0.0020567)
#         porous   : (0 0 0)
#
#
# Time = 0.5s
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 27200 cell(s) with volume 4.41472
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (5.66655 -4.95598 -2.24154e-17)
#         viscous  : (0.237558 -0.00668455 7.60195e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.64656e-18 -2.40129e-18 1.00358)
#         viscous  : (6.53484e-22 5.83877e-22 0.00202368)
#         porous   : (0 0 0)
#
#
# End

# %%
N_startup = 50

plt.figure()
plt.plot(time_bl[N_startup:],forces_bl[(N_startup+1):,1]/(.5*1*20**2*.156*.3))
plt.xlabel('Time (s)')
plt.ylabel('$C_L$')

plt.savefig('CL-vs-Time.png')

plt.figure()
plt.plot(time_bl[N_startup:],forces_bl[(N_startup+1):,0]/(.5*1*20**2*.156*.3))
plt.xlabel('Time (s)')
plt.ylabel('$C_D$')

plt.savefig('CD-vs-Time.png')
# Out:
# Text(0, 0.5, '$C_D$')
