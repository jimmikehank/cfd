# %%
import numpy as np

x = np.loadtxt('/home/james/Documents/research/cfd/coanda_auto/output/X.txt')
dldx = np.loadtxt('/home/james/Documents/research/cfd/coanda_auto/output/dLdX.txt')

resx = x[1,:] - x[0,:]
resg = dldx[1,:] - dldx[0,:]

gamma = 1/np.dot(resg,resg)
print(gamma)

xnew = gamma * dldx[1,:]
print(xnew,x[1,:])



def retrieve_lift(folder, case_iter):
    import os
    file = "{}iteration_{}".format(folder,case_iter)
    os.system('rhoSimpleFoam -case {} -postProcess -func forces -latestTime'.format(file))
    forceFold = os.listdir('{}/postProcessing/forces'.format(file))
    forceFold = forceFold[0]
    sel = []
    with open('{}iteration_{}/postProcessing/forces/{}/forces.dat'.format(folder, case_iter, forceFold)) as f:
        data = f.readlines()[3]
    for i in range(len(data)):
        if data[i] == '(' and data[i+1] == '(':
            j = i
            g = 0
            while g < 2:
                if data[j] == ' ':
                    sel.append(j)
                    g = g + 1
                    j = j+1
                else:
                    j = j+1

            break
    lift = float(data[sel[0]:sel[1]])
    return lift
# Out:
# 1.9998525106133785e-10
# [ 3.06521443e-06 -4.33474767e-06 -5.55736881e-07  0.00000000e+00
#   0.00000000e+00] [3.00120e-03 1.49940e-04 1.79928e-04 5.00000e-01 6.00000e+01]

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 86
folder = "/home/james/Documents/research/converged_cases/"
lift = np.zeros(N)
for i in range(N):
    lift[i] = retrieve_lift(folder,i)
# Out:
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_0 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:40
# Host   : "james-power"
# PID    : 136189
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_0
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010167
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010167
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56989
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.8154 117.751 3.49386e-19)
#         viscous  : (-0.266546 -1.1404 -1.09165e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (1.03854e-21 -2.38461e-20 4.38937)
#         viscous  : (-5.77476e-25 9.25371e-22 -0.141981)
#         porous   : (0 0 0)
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_1 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:40
# Host   : "james-power"
# PID    : 136193
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_1
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010167
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010167
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56989
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.8141 117.768 4.83101e-20)
#         viscous  : (-0.267651 -1.14093 4.17596e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-2.20838e-22 -3.10934e-20 4.38998)
#         viscous  : (9.69805e-23 6.35152e-22 -0.142052)
#         porous   : (0 0 0)
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_2 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:40
# Host   : "james-power"
# PID    : 136195
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_2
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010196
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010196
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56989
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.773 117.908 -2.27214e-19)
#         viscous  : (-0.262208 -1.15759 5.73592e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-2.22084e-22 1.39377e-20 4.38961)
#         viscous  : (1.4595e-22 -3.18101e-21 -0.143958)
#         porous   : (0 0 0)
#
#
# End
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_3 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:40
# Host   : "james-power"
# PID    : 136197
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_3
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.01017
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.01017
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56989
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.8168 118.141 2.41246e-19)
#         viscous  : (-0.256511 -1.14709 -1.56819e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (6.2661e-23 -2.31135e-20 4.40801)
#         viscous  : (-9.40444e-23 3.84306e-21 -0.142936)
#         porous   : (0 0 0)
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_4 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:41
# Host   : "james-power"
# PID    : 136200
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_4
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010134
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010134
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56989
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.8386 118.381 1.65765e-19)
#         viscous  : (-0.247968 -1.14182 -3.08408e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-4.03106e-22 -1.90168e-20 4.42431)
#         viscous  : (-4.16852e-23 9.28987e-22 -0.142518)
#         porous   : (0 0 0)
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_5 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:41
# Host   : "james-power"
# PID    : 136202
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_5
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010116
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010116
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56988
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.8477 118.665 -1.98279e-19)
#         viscous  : (-0.238234 -1.14141 -3.14461e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.80358e-21 2.88464e-20 4.44046)
#         viscous  : (1.3409e-22 -1.52139e-21 -0.14264)
#         porous   : (0 0 0)
#
#
# End
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_6 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:41
# Host   : "james-power"
# PID    : 136204
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_6
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010141
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010141
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56988
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.8481 118.929 -1.86642e-19)
#         viscous  : (-0.230853 -1.14833 4.26082e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.18015e-21 9.31619e-21 4.45188)
#         viscous  : (1.88095e-22 -1.74601e-21 -0.143568)
#         porous   : (0 0 0)
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_7 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:41
# Host   : "james-power"
# PID    : 136206
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_7
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010152
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010152
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56988
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.8403 119.237 1.24403e-19)
#         viscous  : (-0.22155 -1.15726 -3.49143e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (7.07333e-22 -2.16121e-20 4.46497)
#         viscous  : (-1.41046e-22 1.66277e-21 -0.144722)
#         porous   : (0 0 0)
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_8 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:42
# Host   : "james-power"
# PID    : 136208
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_8
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010157
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010157
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56988
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.8154 119.555 -7.2039e-19)
#         viscous  : (-0.210379 -1.16973 4.18505e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-3.42575e-21 6.8643e-20 4.47636)
#         viscous  : (1.87069e-22 -4.25514e-21 -0.146272)
#         porous   : (0 0 0)
#
#
# End
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_9 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:42
# Host   : "james-power"
# PID    : 136210
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_9
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010165
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010165
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56987
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.8312 119.866 3.22432e-19)
#         viscous  : (-0.201201 -1.17143 -3.33208e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (8.37139e-22 -4.38801e-20 4.49313)
#         viscous  : (-8.26059e-23 2.27755e-21 -0.146652)
#         porous   : (0 0 0)
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_10 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:42
# Host   : "james-power"
# PID    : 136212
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_10
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010172
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010172
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56987
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.8514 120.194 9.78155e-20)
#         viscous  : (-0.193713 -1.17104 -4.38784e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (1.32898e-22 -4.81168e-21 4.51187)
#         viscous  : (-3.60141e-23 2.22025e-21 -0.146812)
#         porous   : (0 0 0)
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_11 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:42
# Host   : "james-power"
# PID    : 136214
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_11
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010184
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010184
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56987
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.8563 120.512 -7.50415e-20)
#         viscous  : (-0.183641 -1.17519 -4.9407e-22)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-7.61764e-22 1.70007e-20 4.52778)
#         viscous  : (1.25289e-22 -1.78143e-21 -0.147465)
#         porous   : (0 0 0)
#
#
# End
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_12 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:42
# Host   : "james-power"
# PID    : 136216
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_12
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010207
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010207
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56986
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.8752 120.831 -1.9186e-19)
#         viscous  : (-0.175571 -1.17553 2.53808e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-1.40282e-21 8.31504e-21 4.54556)
#         viscous  : (8.13462e-23 -1.34637e-22 -0.147721)
#         porous   : (0 0 0)
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_13 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:43
# Host   : "james-power"
# PID    : 136218
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_13
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010222
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010222
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56986
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.8899 121.137 -7.10966e-20)
#         viscous  : (-0.1655 -1.1777 8.16952e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (1.97266e-22 2.62939e-20 4.56224)
#         viscous  : (-1.46586e-23 -4.4237e-22 -0.148163)
#         porous   : (0 0 0)
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_14 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:43
# Host   : "james-power"
# PID    : 136220
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_14
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010242
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010242
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56986
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.9111 121.45 3.27503e-19)
#         viscous  : (-0.15659 -1.17834 -8.90889e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-3.22262e-22 -1.66629e-20 4.57988)
#         viscous  : (3.15304e-23 1.40705e-21 -0.148446)
#         porous   : (0 0 0)
#
#
# End
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_15 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:43
# Host   : "james-power"
# PID    : 136222
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_15
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010266
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010266
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56985
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.9372 121.751 -1.94456e-19)
#         viscous  : (-0.149189 -1.1788 1.85231e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (-8.1894e-23 1.02381e-20 4.59744)
#         viscous  : (9.23734e-24 -2.33712e-21 -0.148717)
#         porous   : (0 0 0)
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_16 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:43
# Host   : "james-power"
# PID    : 136224
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_16
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# ...
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56983
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.6404 123.892 1.93883e-19)
#         viscous  : (-0.0201188 -1.25244 -2.91512e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (2.27847e-22 -1.73497e-20 4.68892)
#         viscous  : (-1.80805e-22 8.17936e-22 -0.158442)
#         porous   : (0 0 0)
#
#
# End
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_81 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:57
# Host   : "james-power"
# PID    : 136355
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_81
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010109
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010109
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56983
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.6377 123.901 5.87328e-19)
#         viscous  : (-0.0198953 -1.25321 2.07458e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (2.7264e-21 -3.88339e-20 4.68928)
#         viscous  : (-1.70017e-22 8.67369e-22 -0.158542)
#         porous   : (0 0 0)
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_82 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:57
# Host   : "james-power"
# PID    : 136357
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_82
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.01011
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.01011
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56983
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.6357 123.915 3.65315e-19)
#         viscous  : (-0.0186894 -1.25376 -1.17636e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (2.76207e-21 -1.71237e-21 4.68982)
#         viscous  : (-7.23631e-23 -1.15142e-21 -0.158612)
#         porous   : (0 0 0)
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_83 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:57
# Host   : "james-power"
# PID    : 136359
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_83
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.01011
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.01011
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56983
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.6333 123.922 2.47668e-19)
#         viscous  : (-0.0174656 -1.25405 -2.54319e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (2.68872e-24 -3.76672e-21 4.69019)
#         viscous  : (8.40361e-23 9.73614e-22 -0.158653)
#         porous   : (0 0 0)
#
#
# End
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_84 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:58
# Host   : "james-power"
# PID    : 136361
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_84
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010111
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010111
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56983
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.6321 123.937 -1.51135e-19)
#         viscous  : (-0.015975 -1.25466 2.7009e-20)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (8.54634e-23 -2.18094e-21 4.69088)
#         viscous  : (1.10474e-22 -1.56639e-21 -0.158731)
#         porous   : (0 0 0)
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  9
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 9-b456138dc4bc
# Exec   : rhoSimpleFoam -case /home/james/Documents/research/converged_cases/iteration_85 -postProcess -func forces -latestTime
# Date   : May 19 2022
# Time   : 10:29:58
# Host   : "james-power"
# PID    : 136363
# I/O    : uncollated
# Case   : /home/james/Documents/research/converged_cases/iteration_85
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0.010109
#
#
# SIMPLE: Convergence criteria found
#         p: tolerance 1e-05
#         U: tolerance 1e-05
#         nuTilda: tolerance 1e-05
#
# Time = 0.010109
# Reading thermophysical properties
#
# Selecting thermodynamics package
# {
#     type            hePsiThermo;
#     mixture         pureMixture;
#     transport       const;
#     thermo          hConst;
#     equationOfState perfectGas;
#     specie          specie;
#     energy          sensibleInternalEnergy;
# }
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating turbulence model
#
# Selecting turbulence model type RAS
# Selecting RAS turbulence model SpalartAllmaras
# Selecting patchDistMethod meshWave
# RAS
# {
#     model           SpalartAllmaras;
#     turbulence      on;
#     printCoeffs     on;
#     sigmaNut        0.66666;
#     kappa           0.41;
#     Cb1             0.1355;
#     Cb2             0.622;
#     Cw2             0.3;
#     Cw3             2;
#     Cv1             7.1;
#     Cs              0.3;
# }
#
# Creating thermophysical transport model
#
# Selecting thermophysical transport type RAS
# Selecting default RAS thermophysical transport model unityLewisEddyDiffusivity
# No MRF models present
#
# --> FOAM Warning : Creating fvModels from "system/fvOptions" rather than constant/fvModels
# No fvModels present
# --> FOAM Warning : Creating fvConstraints from "system/fvOptions"
#
# Selecting finite volume constraint type limitTemperature
#     Name: limitT
#     - selecting all cells
#     - selected 23261 cell(s) with volume 3.56983
# forces forces:
#     Not including porosity effects
# forces forces write:
#     sum of forces:
#         pressure : (42.6292 123.949 3.56089e-19)
#         viscous  : (-0.016153 -1.25503 8.73881e-21)
#         porous   : (0 0 0)
#     sum of moments:
#         pressure : (1.33721e-21 -5.2606e-20 4.69134)
#         viscous  : (-1.31998e-22 2.13792e-21 -0.158785)
#         porous   : (0 0 0)
#
#
# End

# %%
plt.figure()
plt.plot(lift/lift[0])

t = np.linspace(0,1,N)
plt.figure()
plt.plot(t,x[:N,0]/x[0,0],t,x[:N,1]/x[0,1],t,lift/lift[0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f6415a4c490>,
#  <matplotlib.lines.Line2D at 0x7f6415a4c3d0>,
#  <matplotlib.lines.Line2D at 0x7f6415a4c340>]
